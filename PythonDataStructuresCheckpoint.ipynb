# %% [markdown]
# Create a program that allows the user to manage their shopping list. The user should be able to add items to the list, remove items, and view the current list of items.
#
# Instructions
# Statement:
#
# Create a list to store the shopping items
# Use a while loop to create a menu of options for the user to add, remove, or view items from the list
# Use a for loop to iterate through the list of items and display them to the user
# Use the range() function to limit the number of items that can be added to the list
# Use the list, tuple, set, and dictionary data structures to store and manipulate the shopping items
# Instructions:
#
# 1. Create a list named 'shopping_list' to store the items.
# 2. Use a while loop to create a menu of options for the user to add, remove, or view items from the list.
# 3. Use the input() function to prompt the user to make a selection from the menu.
# 4. Use an if-elif-else block to determine the user's selection and perform the corresponding action.
# 5. If the user selects 'add', use the input() function to prompt the user to enter an item to add to the list. Use the range() function to limit the number of items that can be added to the list.
# 6. If the user selects 'remove', use the input() function to prompt the user to enter an item to remove from the list.
# 7. If the user selects 'view', use a for loop to iterate through the list of items and display them to the user.
# 8. Use the list, tuple, set, and dictionary data structures to store and manipulate the shopping items.

# %%
shopping_list = []
menushopping = ['1', '2', '3', '4']
print('Menu shopping')

print('------------------------')
print ('1 :  Add Item')
print ('2 :  Remove Item')
print ('3 :  View Items')
print ('4 :  Exit Menu')
print('------------------------')
print('Choose one operation :')
op_shop = input('Your selection : ')

while op_shop in menushopping :
 if op_shop == '1' and len(shopping_list) < 10 :    
        print('Add one Item to your Shoppin list')
        item1 = input ('Adding item :')
        shopping_list.append(item1) 
        shopping_list
        print (f'You added {item1} to your shopping list')
        print('please select : 1 : Add, 2 : Remove, 3 : List, 4 :  Exit Menu')
        op_shop = input('Your selection : 1 : Add, 2 : Remove, 3 : List, 4: Exit menu ')

 elif op_shop == '2' :
        print('Removing Item from shopping list')
        item1 = input ('removing existing item :')
        if item1 not in shopping_list :
          print('Item not found')
          print('please select : 1 : Add, 2 : Remove, 3 : List, 4: Exit menu')
          op_shop = input('Your selection : 1 : Add, 2 : Remove, 3 : List, 4: Exit menu ')
        else :
          shopping_list.remove(item1) 
          print (f'You removed {item1} from your shopping list')
        print('please select : 1 : Add, 2 : Remove, 3 : List, 4: Exit menu')
        op_shop = input('Your selection : 1 : Add, 2 : Remove, 3 : List, 4: Exit menu ')

 elif op_shop == '3' :
        if len(shopping_list) != 0 :
         print('Liste of all Items')
         print (shopping_list)
         tuple1 = tuple(shopping_list)
         print(f'tuple from list :  {tuple1}')
         print('please select : 1 : Add, 2 : Remove, 3 : List, 4: Exit menu')
         op_shop = input('Your selection : 1 : Add, 2 : Remove, 3 : List, 4: Exit menu ')
        else : print('empty list') 
        print('please select : 1 : Add, 2 : Remove, 3 : List, 4: Exit menu')
        op_shop = input('Your selection : 1 : Add, 2 : Remove, 3 : List, 4: Exit menu ')

 elif  op_shop == '4' :
     break

 else :
        print('please select : 1 : Add, 2 : Remove, 3 : List, 4: Exit menu')
        op_shop = input('Your selection : 1 : Add, 2 : Remove, 3 : List, 4: Exit menu ')
        
else :
    print('please select : 1 : Add, 2 : Remove, 3 : List, 4: Exit menu')
    op_shop = input('Your selection : 1 : Add, 2 : Remove, 3 : List, 4: Exit menu ')

# %% [markdown]
# Dictionary , tuple , set , list

# %%
shopping_list = []
shopping_set = set()
shopping_tuple = ()
shopping_dict ={}
menushopping = ['1', '2', '3', '4']

print('Menu shopping')
print('------------------------')
print ('1 :  Add Item')
print ('2 :  Remove Item')
print ('3 :  View Items : List, Set, Tuple, Dictionary')
print ('4 :  Exit Menu')
print('------------------------')
print('Choose one operation :')
op_shop = input('Your selection : ')

while op_shop in menushopping :
 if op_shop == '1' and len(shopping_list) < 5 :    
        print('Add one Item to your Shoppin list')
        item1 = input ('Adding item :')
        shopping_list.append(item1) 
        shopping_list
        shopping_tuple = tuple(shopping_list)
        shopping_tuple
        shopping_set.add(item1)
        shopping_set
        shopping_dict[len(shopping_list)] = item1
        shopping_dict
        print (f'You added  << {item1}  >> to your shopping list')
        print('please select : 1 : Add, 2 : Remove, 3 : List, Set, Tuple, Dictionary 4 :  Exit Menu')
        op_shop = input('Your selection : 1 : Add, 2 : Remove, 3 : List, Set, Tuple, Dictionary, 4: Exit menu ')

 elif op_shop == '2' :
        print('Removing Item from shopping list')
        item1 = input ('removing existing item :')
        if item1 not in shopping_list :
          print('Item not found')
          print('please select : 1 : Add, 2 : Remove, 3 : List, Set, Tuple, Dictionary, 4: Exit menu')
          op_shop = input('Your selection : 1 : Add, 2 : Remove, 3 : List, 4: Exit menu ')
        else :
          shopping_list.remove(item1)
          shopping_set.remove(item1)
          shopping_dict.pop(len(shopping_dict(item1)))

          print (f'You removed << {item1} >> from your shopping list')
        print('please select : 1 : Add, 2 : Remove, 3 : List, Set, Tuple, Dictionary, 4: Exit menu')
        op_shop = input('Your selection : 1 : Add, 2 : Remove, 3 : List, Set, Tuple, Dictionary, 4: Exit menu ')

 elif op_shop == '3' :
        if len(shopping_list) != 0 :
         print('List, tuple, set and dictionary of shopping list')
         print (f'List : {shopping_list}')
         print (f' Tuple : {shopping_tuple}')
         print(f' Set : {shopping_set}')
         print(f' Dictionary : {shopping_dict}')
         print('please select : 1 : Add, 2 : Remove, 3 : List, Set, Tuple, Dictionary, 4: Exit menu')
         op_shop = input('Your selection : 1 : Add, 2 : Remove, 3 : List, Set, Tuple, Dictionary, 4: Exit menu ')
        else : print('empty list') 
        print('please select : 1 : Add, 2 : Remove, 3 : List, Set, Tuple, Dictionary, 4: Exit menu')
        op_shop = input('Your selection : 1 : Add, 2 : Remove, 3 : List, Set, Tuple, Dictionary, 4: Exit menu ')

 elif  op_shop == '4' :
     break

 else :
        print('please select : 1 : Add, 2 : Remove, 3 : List, Set, Tuple, Dictionary, 4: Exit menu')
        op_shop = input('Your selection : 1 : Add, 2 : Remove, 3 : List, Set, Tuple, Dictionary, 4: Exit menu ')
        
else :
    print('please select : 1 : Add, 2 : Remove, 3 : List, Set, Tuple, Dictionary, 4: Exit menu')
    op_shop = input('Your selection : 1 : Add, 2 : Remove, 3 : List, Set, Tuple, Dictionary, 4: Exit menu ')
# Out:
# Menu shopping
# ------------------------
# 1 :  Add Item
# 2 :  Remove Item
# 3 :  View Items : List, Set, Tuple, Dictionary
# 4 :  Exit Menu
# ------------------------
# Choose one operation :
# Add one Item to your Shoppin list
# You added  << 11  >> to your shopping list
# please select : 1 : Add, 2 : Remove, 3 : List, Set, Tuple, Dictionary 4 :  Exit Menu
# Add one Item to your Shoppin list
# You added  << 12  >> to your shopping list
# please select : 1 : Add, 2 : Remove, 3 : List, Set, Tuple, Dictionary 4 :  Exit Menu
# Add one Item to your Shoppin list
# You added  << 13  >> to your shopping list
# please select : 1 : Add, 2 : Remove, 3 : List, Set, Tuple, Dictionary 4 :  Exit Menu
# Add one Item to your Shoppin list
# You added  << 14  >> to your shopping list
# please select : 1 : Add, 2 : Remove, 3 : List, Set, Tuple, Dictionary 4 :  Exit Menu
# Add one Item to your Shoppin list
# You added  << 15  >> to your shopping list
# ...
